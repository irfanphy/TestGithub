# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=np.loadtxt('SdH1.dat')

# %%
B=data[:, 0]
Rxx=data[:, 3]

# %%
plt.plot(1/B[3000:], Rxx[3000:])

# %%
W=np.fft.rfft(Rxx[3000:])

# %%
plt.plot(np.abs(W))
plt.ylim([0, 1000])
# Out:
# (0, 1000)
